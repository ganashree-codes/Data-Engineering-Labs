# %%
#Python is commanly used in data engineering
print("Welcome to Data Engineering with Python")
# Out:
# Welcome to Data Engineering with Python

# %%
print("Step 1:Read data")
print("Step 2:Clean data")
print("Step 3:Write data")
# Out:
# Step 1:Read data
# Step 2:Clean data
# Step 3:Write data

# %%
customer_name="Asha Patel"
customer_id=101
active=True
print(f"Customer {customer_id} : {customer_name} (Active:{active})")
# Out:
# Customer 101 : Asha Patel (Active:True)

# %%
a=250
b=99.95
c="Mumbai"
d=False
print(f"value:{a}, Type: {type(a)} ")
print(f"value:{b}, Type: {type(b)} ")
print(f"value:{c}, Type: {type(c)} ")
print(f"value:{d}, Type: {type(d)} ")
# Out:
# value:250, Type: <class 'int'>
# value:99.95, Type: <class 'float'>
# value:Mumbai, Type: <class 'str'>
# value:False, Type: <class 'bool'>

# %%
mark1="78"
mark1 = int(mark1)
mark2="85.5"
mark2 = float(mark2)
Total_marks=mark1+mark2
print(f"Total marks: {Total_marks:.1f}")
# Out:
# Total marks: 163.5

# %%
item_price=249.99
quantity=3
tax_rate=0.05 # 5%
subtotal=item_price*quantity
tax=subtotal*tax_rate
grand_total=subtotal+tax
print(f"Grand Total : {grand_total:.2f}")
# Out:
# Grand Total : 787.47

# %%
order1 = 1200
order2 = 999
 
print("Is order1 > order2?", order1 > order2)
print("Are order1 and order2 equal?", order1 == order2)
# Out:
# Is order1 > order2? True
# Are order1 and order2 equal? False

# %%
price= 1500
in_stock=True

print("High value and available?", price > 1000 and in_stock==True)
print("High value or out of stock?", price > 1000 or in_stock==False)
# Out:
# High value and available? True
# High value or out of stock? True

# %%
name=input("Enter customer name:")
amount=input("Enter customer amount:")
amount=float(amount)
print(f"Receipt--Customer:{name},Amount:{amount:.2f}")
# Out:
# Enter customer name: Raj
# Enter customer amount: 350.5
# Receipt--Customer:Raj,Amount:350.50

# %%
product="SSD"
price=12999.5
price=float(price)
qty=2
total=qty*price
print(f"Order: {qty} * {product} @ {price:.2f} each -- Total : {total:.2f}")
# Out:
# Order: 2 * SSD @ 12999.50 each -- Total : 25999.00

# %%
#Nameerror fix
name="Neha"
print(name)
# Out:
# Neha

# %%
#Typeerror fix
age="30"
print("Age next year:",int(age)+1)
# Out:
# Age next year: 31

# %%
#valueerror debugging
value="123"
num=int(value)
print(num)
# Out:
# 123

# %%
m1="78"
m1=int(m1)
m2="85"
m2=int(m2)
m3="69"
m3=int(m3)
total=m1+m2+m3
Percentage=(total/300)*100
print(f"percentage: {Percentage:.2f}")
if Percentage >= 35:
   print("Result:Pass")
else:
    print("Result:Fail")
# Out:
# percentage: 77.33
# Result:Pass

# %%
original_price=4999.99
discount_percent=12.5
discount_amount=original_price*(discount_percent/100)
final_price=original_price-discount_amount
print(f"Discount: {discount_amount:.2f}")
print(f"Final Price: {final_price:.2f}")
# Out:
# Discount: 625.00
# Final Price: 4374.99

# %%
#customer_details
name="Rohan Verma"
id="205"

#purchase details
item="Textbook"
unit_price="450.5"
quantity="2"
id=int(id)
unit_price=float(unit_price)
quantity=int(quantity)
subtotal=unit_price*quantity
tax=subtotal*(5/100)
grand_total=subtotal+tax
print(f"Customer ID:{id}")
print(f"Customer Name: {name}")
print(f"Item:{item}")
print(f"Quantity:{quantity}")
print(f"Subtotal:{subtotal:.2f}")
print(f"Tax:{tax:.2f}")
print(f"Grand Total:{grand_total:.2f}")
print(f"Customer ID:{id} Customer Name: {name} Item:{item} Quantity:{quantity} Subtotal:{subtotal:.2f} Tax(5%):{tax:.2f} Grand Total:{grand_total:.2f}")
# Out:
# Customer ID:205
# Customer Name: Rohan Verma
# Item:Textbook
# Quantity:2
# Subtotal:901.00
# Tax:45.05
# Grand Total:946.05
# Customer ID:205 Customer Name: Rohan Verma Item:Textbook Quantity:2 Subtotal:901.00 Tax(5%):45.05 Grand Total:946.05
